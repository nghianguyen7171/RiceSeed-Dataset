# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
#BC15
Data = pd.read_csv('BC15.csv', encoding = "ISO-8859-1")
Data.head()
# Out:
#    ID  Species        Lk      P1P2      P3P4        hC        dK        dL  \
# 0   1        1  0.122490  0.244684  0.249862  0.083052  0.003457  0.017602
# 1   2        1  0.116376  0.247567  0.243658  0.081248  0.004430  0.016801
# 2   3        1  0.106072  0.264595  0.247113  0.064979  0.005444  0.017563
# 3   4        1  0.100475  0.249979  0.234652  0.075062  0.006403  0.020503
# 4   5        1  0.109839  0.236233  0.252525  0.085421  0.006144  0.018098
#
#          phi   Area  Perimeter  Eccentricity         CD          AB     CD/AB
# 0  64.177188  12816   0.040090      0.951008  68.594114  233.602110  0.293637
# 1  23.432626  12998   0.040239      0.951188  69.000007  237.196388  0.290898
# 2  77.753203  12945   0.040010      0.947297  69.583377  232.831033  0.298858
# 3  40.005291  12410   0.040555      0.944751  71.625572  228.206647  0.313863
# 4  28.416404  13093   0.039914      0.947095  71.854954  236.946491  0.303254

# %%
#BC15-EC
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
#Data[['Eccentricity']].plot(kind='hist', bins=[0.93,0.94,0.95,0.96])
Data['Eccentricity'].plot.hist(10)

plt.show()
#=  2LOG(2)+4LOG(4)+10LOG(10)+9LOG(9)+11LOG(11)+15LOG(15)+13LOG(13)+9LOG(9)+3LOG(3)+4LOG(4)

# %%
sns.kdeplot(Data['Eccentricity'])

# %%
# BC15-CD/AB
Data['CD/AB'].plot.hist(10)

# %%
sns.kdeplot(Data['CD/AB'])

# %%
#bc15-cd
Data['CD'].plot.hist(10)

# %%
sns.kdeplot(Data['CD'])

# %%
#BC15-P3P4
Data['P3P4'].plot.hist(10)

# %%
sns.kdeplot(Data['P3P4'])

# %%
#BC15-AB
Data['AB'].plot.hist(10)

# %%
sns.kdeplot(Data['AB'])

# %%
#BC15-P1P2
Data['P1P2'].plot.hist(10)

# %%
sns.kdeplot(Data['P1P2'])

# %%
#BC15-AREA
Data['Area'].plot.hist(10)

# %%
sns.kdeplot(Data['Area'])

# %%
#BC15-Perimeter
Data['Perimeter'].plot.hist(10)

# %%
sns.kdeplot(Data['Perimeter'])

# %%
#BC15-dK
Data['dK'].plot.hist(10)

# %%
sns.kdeplot(Data['dK'])

# %%
#BC15-dL 
Data['dL'].plot.hist(10)

# %%
sns.kdeplot(Data['dL'])

# %%
#BC15-phi  
Data['phi'].plot.hist(10)

# %%
sns.kdeplot(Data['phi'])

# %%
#BC15-Lk   
Data['Lk'].plot.hist(10)

# %%
sns.kdeplot(Data['Lk'])

# %%
#BC15-hC 
Data['hC'].plot.hist(10)

# %%
sns.kdeplot(Data['hC'])

# %%
Data = pd.read_csv('BQ10.csv', encoding = "ISO-8859-1")
Data.head()
# Out:
#     ID  Species        Lk      P1P2      P3P4        hC        dK        dL  \
# 0   97        2  0.177054  0.302788  0.271698  0.089795  0.005553  0.015057
# 1   98        2  0.115667  0.288090  0.286428  0.077701  0.005641  0.018360
# 2   99        2  0.154213  0.309334  0.279713  0.084375  0.005107  0.018886
# 3  100        2  0.112696  0.292557  0.277274  0.060511  0.013959  0.009493
# 4  101        2  0.108222  0.287448  0.263216  0.062753  0.006614  0.017235
#
#          phi   Area  Perimeter  Eccentricity         CD          AB     CD/AB
# 0  77.707354  13610   0.037407      0.936591  74.127128  223.606727  0.331507
# 1  94.493219  13737   0.036949      0.933253  77.199846  225.755000  0.341963
# 2  53.449023  13909   0.036767      0.936849  74.823615  226.148563  0.330860
# 3  47.524027  13741   0.036680      0.928564  77.799725  223.808562  0.347617
# 4  49.517296  13525   0.037957      0.939456  73.135239  231.180096  0.316356

# %%
#BQ10
Data['Eccentricity'].plot.hist(10)
plt.show()

# %%
sns.kdeplot(Data['Eccentricity'])

# %%
Data['CD/AB'].plot.hist(10)

# %%
sns.kdeplot(Data['CD/AB'])

# %%
Data['CD'].plot.hist(10)

# %%
sns.kdeplot(Data['CD'])

# %%
Data['P3P4'].plot.hist(10)

# %%
sns.kdeplot(Data['P3P4'])

# %% [markdown]
# Data['AB'].plot.hist(10)

# %%
sns.kdeplot(Data['AB'])

# %%
Data['P1P2'].plot.hist(10)

# %%
sns.kdeplot(Data['P1P2'])

# %%
Data['Area'].plot.hist(10)

# %%
sns.kdeplot(Data['Area'])

# %%
Data['Perimeter'].plot.hist(10)

# %%
sns.kdeplot(Data['Perimeter'])

# %%
Data['dK'].plot.hist(10)

# %%
sns.kdeplot(Data['dK'])

# %%
Data['dL'].plot.hist(10)

# %%
sns.kdeplot(Data['dL'])

# %%
Data['phi'].plot.hist(10)

# %%
sns.kdeplot(Data['phi'])

# %%
Data['Lk'].plot.hist(10)

# %%
sns.kdeplot(Data['Lk'])

# %%
Data['hC'].plot.hist(10)

# %%
sns.kdeplot(Data['hC'])

# %%
# NH92
Data = pd.read_csv('NH92.csv', encoding = "ISO-8859-1")
Data.head()
# Out:
#     ID  Species        Lk      P1P2      P3P4        hC        dK        dL  \
# 0  193        3  0.128427  0.236961  0.254486  0.111455  0.000598  0.028310
# 1  194        3  0.083317  0.239507  0.255752  0.065281  0.005844  0.018358
# 2  195        3  0.148263  0.249727  0.257568  0.104692  0.005056  0.011989
# 3  196        3  0.105561  0.251240  0.245021  0.073802  0.002571  0.012831
# 4  197        3  0.102047  0.239950  0.233136  0.070505  0.006266  0.009675
#
#          phi   Area  Perimeter  Eccentricity         CD          AB     CD/AB
# 0  79.194575  12240   0.042264      0.953484  64.584990  233.754064  0.276295
# 1  73.434908  12370   0.041222      0.952512  66.485690  231.575256  0.287102
# 2  39.651599  12307   0.041503      0.951382  64.888879  230.478487  0.281540
# 3  75.588841  12313   0.041057      0.949377  66.536466  229.241510  0.290246
# 4  42.956597  12035   0.042199      0.953370  64.589594  233.804194  0.276255

# %%
Data['Eccentricity'].plot.hist(10)

# %%
sns.kdeplot(Data['Eccentricity'])

# %%
Data['CD/AB'].plot.hist(10)

# %%
sns.kdeplot(Data['CD/AB'])

# %%
Data['CD'].plot.hist(10)

# %%
sns.kdeplot(Data['CD'])

# %%
Data['P3P4'].plot.hist(10)

# %%
sns.kdeplot(Data['P3P4'])

# %%
Data['AB'].plot.hist(10)

# %%
sns.kdeplot(Data['AB'])

# %%
Data['P1P2'].plot.hist(10)

# %%
sns.kdeplot(Data['P1P2'])

# %%
Data['Area'].plot.hist(10)

# %%
sns.kdeplot(Data['Area'])

# %%
Data['Perimeter'].plot.hist(10)

# %%
sns.kdeplot(Data['Perimeter'])

# %%
Data['dK'].plot.hist(10)

# %%
sns.kdeplot(Data['dK'])

# %%
Data['dL'].plot.hist(10)

# %%
sns.kdeplot(Data['dL'])

# %%
Data['phi'].plot.hist(10)

# %%
sns.kdeplot(Data['phi'])

# %%
Data['Lk'].plot.hist(10)

# %%
sns.kdeplot(Data['Lk'])

# %%
Data['hC'].plot.hist(10)

# %%
sns.kdeplot(Data['hC'])

# %%
# NT16
Data = pd.read_csv('NT16.csv', encoding = "ISO-8859-1")
Data.head()
# Out:
#     ID  Species        Lk      P1P2      P3P4        hC        dK        dL  \
# 0  294        4  0.092715  0.303376  0.287586  0.062649  0.014768  0.014683
# 1  295        4  0.118512  0.297845  0.307699  0.064163  0.006380  0.023030
# 2  296        4  0.135177  0.290773  0.293444  0.097782  0.005645  0.025333
# 3  297        4  0.129843  0.293835  0.292369  0.066234  0.004055  0.016543
# 4  298        4  0.139438  0.311522  0.287785  0.018014  0.002636  0.018288
#
#           phi   Area  Perimeter  Eccentricity         CD          AB     CD/AB
# 0   91.043899  12954   0.037420      0.921708  78.272412  213.608867  0.366429
# 1   90.145020  13538   0.036477      0.922627  78.772532  218.618477  0.360320
# 2   99.019259  13236   0.037629      0.927033  76.122524  220.112053  0.345835
# 3  105.781027  13045   0.037465      0.924387  77.962190  216.349290  0.360353
# 4  144.013845  13439   0.037122      0.925810  76.771062  217.982192  0.352190

# %%
Data['Eccentricity'].plot.hist(10)

# %%
sns.kdeplot(Data['Eccentricity'])

# %%
Data['CD/AB'].plot.hist(10)

# %%
sns.kdeplot(Data['CD/AB'])

# %%
Data['CD'].plot.hist(10)

# %%
sns.kdeplot(Data['CD'])

# %%
Data['P3P4'].plot.hist(10)

# %%
sns.kdeplot(Data['P3P4'])

# %%
Data['AB'].plot.hist(10)

# %%
sns.kdeplot(Data['AB'])

# %%
Data['P1P2'].plot.hist(10)

# %%
sns.kdeplot(Data['P1P2'])

# %%
Data['Area'].plot.hist(10)

# %%
sns.kdeplot(Data['Area'])

# %%
sns.kdeplot(Data['Area'])

# %%
sns.kdeplot(Data['Perimeter'])

# %%
Data['dK'].plot.hist(10)

# %%
sns.kdeplot(Data['dK'])

# %%
Data['dL'].plot.hist(10)

# %%
sns.kdeplot(Data['dL'])

# %%
Data['phi'].plot.hist(10)

# %%
sns.kdeplot(Data['phi'])

# %%
Data['Lk'].plot.hist(10)

# %%
sns.kdeplot(Data['Lk'])

# %%
Data['hC'].plot.hist(10)

# %%
sns.kdeplot(Data['hC'])

# %%
# PC10
Data = pd.read_csv('PC10.csv', encoding = "ISO-8859-1")
Data.head()
# Out:
#     ID  Species        Lk      P1P2      P3P4        hC        dK        dL  \
# 0  385        5  0.080695  0.196250  0.187319  0.092862  0.005133  0.018749
# 1  386        5  0.097220  0.214400  0.213476  0.087326  0.015046  0.020653
# 2  387        5  0.104653  0.208815  0.225980  0.090351  0.003292  0.013240
# 3  388        5  0.096056  0.219688  0.218307  0.081686  0.012861  0.017000
# 4  389        5  0.099830  0.195062  0.215387  0.074296  0.007586  0.014368
#
#           phi   Area  Perimeter  Eccentricity         CD          AB     CD/AB
# 0   74.069875  11426   0.047868      0.968865  55.769162  252.348870  0.221000
# 1  114.558445  12338   0.044899      0.965727  61.011431  253.007569  0.241145
# 2   33.827706  11703   0.044779      0.963952  58.529978  241.279692  0.242581
# 3  111.027681  12563   0.044264      0.964578  61.062593  251.233560  0.243051
# 4   28.339792  12186   0.044426      0.965064  61.383567  251.182918  0.244378

# %%
Data['Eccentricity'].plot.hist(10)

# %%
sns.kdeplot(Data['Eccentricity'])

# %%
Data['CD/AB'].plot.hist(10)

# %%
sns.kdeplot(Data['CD/AB'])

# %%
Data['CD'].plot.hist(10)

# %%
sns.kdeplot(Data['CD'])

# %%
Data['P3P4'].plot.hist(10)

# %%
sns.kdeplot(Data['P3P4'])

# %%
Data['AB'].plot.hist(10)

# %%
sns.kdeplot(Data['AB'])

# %%
Data['P1P2'].plot.hist(10)

# %%
sns.kdeplot(Data['P1P2'])

# %%
Data['Area'].plot.hist(10)

# %%
sns.kdeplot(Data['Area'])

# %%
Data['Perimeter'].plot.hist(10)

# %%
sns.kdeplot(Data['Perimeter'])

# %%
Data['dK'].plot.hist(10)

# %%
sns.kdeplot(Data['dK'])

# %%
Data['dL'].plot.hist(10)

# %%
sns.kdeplot(Data['dL'])

# %%
Data['phi'].plot.hist(10)

# %%
sns.kdeplot(Data['phi'])

# %%
Data['Lk'].plot.hist(10)

# %%
sns.kdeplot(Data['Lk'])

# %%
Data['hC'].plot.hist(10)

# %%
sns.kdeplot(Data['hC'])

# %%
# VietHuong8
Data = pd.read_csv('VietHuong8.csv', encoding = "ISO-8859-1")
Data.head()
# Out:
#     ID  Species        Lk      P1P2      P3P4        hC        dK        dL  \
# 0  481        6  0.081001  0.232813  0.234871  0.064015  0.013546  0.013449
# 1  482        6  0.084065  0.237357  0.225283  0.062555  0.010768  0.012074
# 2  483        6  0.122481  0.249806  0.242459  0.092012  0.005949  0.016219
# 3  484        6  0.094107  0.229415  0.226955  0.077136  0.009283  0.016171
# 4  485        6  0.128971  0.244229  0.240937  0.075733  0.008428  0.009182
#
#          phi   Area  Perimeter  Eccentricity         CD          AB     CD/AB
# 0  25.373023  13893   0.040565      0.962133  63.700444  255.490182  0.249326
# 1  30.032072  13649   0.040608      0.959655  65.417385  252.504302  0.259074
# 2  73.648685  14036   0.039314      0.955682  69.610138  250.635597  0.277734
# 3  39.215680  14254   0.039636      0.957033  69.846898  257.027194  0.271749
# 4  78.938625  13848   0.039451      0.955390  68.968400  248.305287  0.277756

# %%
Data['Eccentricity'].plot.hist(10)

# %%
sns.kdeplot(Data['Eccentricity'])

# %%
Data['CD/AB'].plot.hist(10)

# %%
sns.kdeplot(Data['CD/AB'])

# %%
Data['CD'].plot.hist(10)

# %%
sns.kdeplot(Data['CD'])

# %%
Data['P3P4'].plot.hist(10)

# %%
sns.kdeplot(Data['P3P4'])

# %%
Data['AB'].plot.hist(10)

# %%
sns.kdeplot(Data['AB'])

# %%
Data['P1P2'].plot.hist(10)

# %%
sns.kdeplot(Data['P1P2'])

# %%
Data['Area'].plot.hist(10)

# %%
sns.kdeplot(Data['Area'])

# %%
Data['Perimeter'].plot.hist(10)

# %%
sns.kdeplot(Data['Perimeter'])

# %%
Data['dK'].plot.hist(10)

# %%
sns.kdeplot(Data['dK'])

# %%
Data['dL'].plot.hist(10)

# %%
sns.kdeplot(Data['dL'])

# %%
Data['phi'].plot.hist(10)

# %%
sns.kdeplot(Data['phi'])

# %%
Data['Lk'].plot.hist(10)

# %%
sns.kdeplot(Data['Lk'])

# %%
Data['hC'].plot.hist(10)

# %%
sns.kdeplot(Data['hC'])
